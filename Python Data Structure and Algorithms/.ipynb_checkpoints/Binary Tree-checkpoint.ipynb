# %% [markdown]
# basically in tree we have the main node known as ROOT node also we can call them PARENTS after that we have CHILD
# and they have furthur child. Last node that have no children known as LEAF node, SIBLINGS are the child of same parents

# %% [markdown]
# ### always remember in base case consider the single root node case than it will be easy to complt que

# %%
class BinaryTreeNode: 
    def __init__(self,data):
        self.data = data
        self.right = None
        self.left = None
    
def printtree(root):
    if root is None:
        return
    print(root.data,end=': ')
    if root.left is not None:
        print('L',root.left.data,end=', ')
    if root.right is not None:
        print('R',root.right.data,end='')
    print()
    printtree(root.left)
    printtree(root.right)
    
def treeinput():  #here input we've taken is complex so we'll take another way ahead which will be used throughout
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root  # we return root from here because suppose for left sub tree we have to return root of the left
# tree as the root of left is attach with it's left and right so we have to return root as it is linked with all
#it's part
        
root = treeinput()
printtree(root)
# Out:
# 1
# 2
# 4
# -1
# -1
# 5
# -1
# -1
# 3
# -1
# -1
# 1: L 2, R 3
# 2: L 4, R 5
# 4:
# 5:
# 3:

# %% [markdown]
#  printing
#
#
#  post order
#
# def postOrder(root):
#     if root is None:
#         return None
#     postOrder(root.left)
#     postOrder(root.right)
#     print(root.data,end=' ')
#     pass
#
#  pre order
#
# def preOrder(root):
#     if root is None:
#         return None
#     print(root.data,end=' ')
#     preOrder(root.left)
#     preOrder(root.right)

# %% [markdown]
# ### num of Nodes

# %%
class BinaryTreeNode:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None

def treeinput():
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root

def sumnode(root):
    if root is None:
        return 0
    left_count = sumnode(root.left)
    right_count = sumnode(root.right)
    return 1+left_count+right_count  # 1 is because of the root for eg 1: 2,3  first 1 it's not None then 2 the
# left part then 2's left is none it will return 0 and 2's right will return 0 the final return from left tree
# will be 1+0+0 same for right tree.

root = treeinput()
print('total no of nodes are')
print(sumnode(root))
# Out:
# 1
# 2
# -1
# -1
# 3
# -1
# -1
# total no of nodes are
# 3

# %% [markdown]
# ### Sum of all nodes

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def sumOfAllNodes(root):
    if root is None:
        return 0
    root_data = root.data
    left_data = sumOfAllNodes(root.left)
    right_data = sumOfAllNodes(root.right)
    return root_data+left_data+right_data
    pass

def buildLevelTree(levelorder):   # ispr dhyan na de aage smjh aajaega main def pr dhyan de.
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
print(sumOfAllNodes(root))
# Out:
# 5 6 10 2 3 -1 -1 -1 -1 -1 9 -1 -1
# 35

# %% [markdown]
# ### largest data

# %%
class BinaryTreeNode:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
        
def treeinput():
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root

def largestdata(root):
    if root is None:
        return -1
    left_largest_data = largestdata(root.left)
    right_largest_data = largestdata(root.right)
    largest = max(left_largest_data,right_largest_data,root.data)
    return largest

root = treeinput()
largest = largestdata(root)
print('largest data is', largest)
# Out:
# 10
# 20
# 30
# -1
# -1
# 40
# -1
# -1
# 50
# -1
# -1
# largest data is 50

# %% [markdown]
# ### Greater than x

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def countNodesGreaterThanX(root, x):
    # Given a Binary Tree and an integer x, find and return the count of nodes
    # which are having data greater than x.
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    if root is None:
        return 0
    count = 0
    if root.data > x:
        count+=1
    count+=countNodesGreaterThanX(root.left, x)
    count+=countNodesGreaterThanX(root.right, x)
    return count
    pass

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
x=int(input())
root = buildLevelTree(levelOrder)
print(countNodesGreaterThanX(root, x))
# Out:
# 1 -1 2 -1 3 -1 4 -1 5 -1 -1
# 3
# 2

# %% [markdown]
# ### Height of tree

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def height(root):
    # Find the Height Of Binary Tree
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    if root is None:
        return 0
    left_height = height(root.left)
    right_height = height(root.right)
    height_1 = max(left_height,right_height) + 1
    return height_1
    

def buildLevelTree():
    
    root = BinaryTreeNode(int(input()))
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = int(input())
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = int(input())
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
root = buildLevelTree()
print(height(root))   # 5 is the answer
# Out:
# 10
# 9
# 4
# -1
# -1
# 5
# 8
# -1
# 6
# -1
# -1
# 3
# -1
# -1
# -1
# 5

# %% [markdown]
# ### Number of leaf node

# %% [markdown]
# here the tricky part is that we have to see thr main root investement for eg if we have only one node thats all
# in that case the leaf node is 1 but if main root node have some branches than the contribution of root for leaf
# will not be counted

# %%
class BinaryTreeNode:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
        
def treeinput():
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root

def num_of_leaf(root):
    if root is None:
        return 0
    if root.left is None and root.right is None:
        return 1
    left_leaf = num_of_leaf(root.left)
    right_leaf = num_of_leaf(root.right)
    return left_leaf+right_leaf

root = treeinput()
print(num_of_leaf(root))
# Out:
# 1
# 2
# -1
# -1
# -1
# 1

# %% [markdown]
# ### Nodes at depth K

# %%
class BinaryTreeNode:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
        
def treeinput():
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root

def PrintDepthK(root,k):
    if root is None:
        return
    if k==0:
        print(root.data)
        return
    PrintDepthK(root.left,k-1)  #here we are doing k-1 because from root we jump to left tree now for the left 
    # tree the depth is now k-1 as we have excluded the root same for the right part
    PrintDepthK(root.right,k-1)
    
def PrintDepthKv2(root,k,d=0):
    if root is None:
        return
    if k==d:
        print(root.data)
        return
    PrintDepthKv2(root.left,k,d+1)  # here d represent the depth as we go down in leaf we will increase the depth
    # as depth equals to the k we print the entire level
    PrintDepthKv2(root.right,k,d+1)
    
root = treeinput()
PrintDepthKv2(root,2)   # 4 and 5 is the answer
PrintDepthK(root,1)  # 2 and 3 is the answer   here root is count as 0 depth
# Out:
# 1
# 2
# 4
# -1
# -1
# 5
# -1
# -1
# 3
# -1
# -1
# 4
# 5
# 2
# 3

# %% [markdown]
# ### Replace node with depth

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def replaceWithDepth(root,level=0):
    # Given a Binary Tree and an integer x, find and return the count of nodes
    # which are having data greater than x.
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    if root is None:
        return
    root.data = level
    replaceWithDepth(root.left,level+1)
    replaceWithDepth(root.right,level+1)
    return root
    
def treeinput():
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root

def printtree(root):
    if root is None:
        return
    print(root.data,end=': ')
    if root.left is not None:
        print('L',root.left.data,end=', ')
    if root.right is not None:
        print('R',root.right.data,end='')
    print()
    printtree(root.left)
    printtree(root.right)

root = treeinput()
root = replaceWithDepth(root)
printtree(root)
# Out:
# 1
# 2
# 4
# -1
# -1
# 5
# -1
# -1
# 3
# -1
# -1
# 0: L 1, R 1
# 1: L 2, R 2
# 2:
# 2:
# 1:

# %% [markdown]
# ### Remove leaf nodes

# %%
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None
    
def treeinput():
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root

def printtree(root):
    if root is None:
        return
    print(root.data,end=': ')
    if root.left is not None:
        print('L',root.left.data,end=', ')
    if root.right is not None:
        print('R',root.right.data,end='')
    print()
    printtree(root.left)
    printtree(root.right)

def removeleaves(root):
    if root is None:
        return None
    if root.left is None and root.right is None:
        return None  # this is the case when the input is only root nothing else so it will be leaf, so remove
    root.left = removeleaves(root.left)
    root.right = removeleaves(root.right)
    return root

root = treeinput()
root = removeleaves(root)
printtree(root)
# Out:
# 1
# 2
# 4
# -1
# -1
# 5
# -1
# -1
# 3
# -1
# -1
# 1: L 2,
# 2:

# %% [markdown]
# ### Mirror tree

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def mirrorBinaryTree(root):
    # Mirror the given binary tree. That is, right child of every nodes should
    # become left and left should become right.
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################   simply focus on this function rest leave for now but understand it later.
    if root is None:
        return 
    if root.left is None and root.right is None:
        return root
    root.left,root.right = root.right,root.left
    left_tree = mirrorBinaryTree(root.left)
    right_tree = mirrorBinaryTree(root.right)
    left_tree,right_tree = right_tree,left_tree
    pass

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Problem ID 353, Level order traversal
def printLevelATNewLine(root):
    # Given a binary tree, print the level order traversal. Make sure each level
    # start in new line.
    if root==None:
        return
    inputQ = queue.Queue()
    outputQ = queue.Queue()
    inputQ.put(root)
    while not inputQ.empty():
        while not inputQ.empty():
            curr = inputQ.get()
            print(curr.data, end=' ')
            if curr.left!=None:
                outputQ.put(curr.left)
            if curr.right!=None:
                outputQ.put(curr.right)
        print()
        inputQ, outputQ = outputQ, inputQ

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
mirrorBinaryTree(root)
printLevelATNewLine(root)
# Out:
# 647 269 852 176 305 835 938 -1 -1 -1 606 -1 845 -1 1159 -1 -1 -1 -1 -1 -1
# 647
# 852 269
# 938 835 305 176
# 1159 845 606

# %% [markdown]
# ### Is tree balanced?

# %%
class BinaryTreeNode:                 # not a optimal solution
    def __init__(self,data):
        self.data = data
        self.right = None
        self.left = None
    
def printtree(root):
    if root is None:
        return
    print(root.data,end=': ')
    if root.left is not None:
        print('L',root.left.data,end=', ')
    if root.right is not None:
        print('R',root.right.data,end='')
    print()
    printtree(root.left)
    printtree(root.right)
    
def treeinput():  #here input we've taken is complex so we'll take another way ahead which will be used throughout
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root

def height(root):
    if root is None:
        return 0
    return 1+max(height(root.left),height(root.right))

def isbalanced(root):
    if root is None:
        return True
    lh = height(root.left)
    rh = height(root.right)
    if lh-rh>1 or rh-lh>1:
        return False
    right_balance = isbalanced(root.right)
    left_balance = isbalanced(root.left)
    if right_balance and left_balance:
        return True
    else:
        return False
    
root = treeinput()
printtree(root)
print(isbalanced(root))

# time complexity for worst case is o(n**2) and min is o(nlogn)...worst is when only right child n times and 
# good one is the perect balanced tree every node has 2 childs
# Out:
# 1
# 2
# 4
# 6
# -1
# -1
# -1
# -1
# 3
# -1
# 5
# -1
# -1
# 1: L 2, R 3
# 2: L 4,
# 4: L 6,
# 6:
# 3: R 5
# 5:
# False

# %%
# another method but this one has time complexity as o(n)
class BinaryTreeNode:   
    def __init__(self,data):
        self.data = data
        self.right = None
        self.left = None
    
def printtree(root):
    if root is None:
        return
    print(root.data,end=': ')
    if root.left is not None:
        print('L',root.left.data,end=', ')
    if root.right is not None:
        print('R',root.right.data,end='')
    print()
    printtree(root.left)
    printtree(root.right)
    
def treeinput():  #here input we've taken is complex so we'll take another way ahead which will be used throughout
    root_data = int(input())
    if root_data is -1:
        return None
    root = BinaryTreeNode(root_data)
    left_tree = treeinput()
    right_tree = treeinput()
    root.left = left_tree
    root.right = right_tree
    return root

def GetHeighAndCheckBalanced(root):
    if root is None:    #here if root is None than h=0 and its True.
        return 0,True
    lh,isBalancedleft = GetHeighAndCheckBalanced(root.left) #checking and taking height together so there is no 
    # for height function because of it complx was o(n**2)...take a look at above part and than compare.
    rh,isBalancedright = GetHeighAndCheckBalanced(root.right)
    
    h = 1+max(lh,rh)
    if lh-rh>1 or rh-lh>1:
        return h,False
    if isBalancedleft and isBalancedright:
        return h,True
    else:
        return h,False

    # if we want only boolean than

def isBalanced2(root):
    h,isRootbalanced = GetHeighAndCheckBalanced(root)
    return isRootbalanced
    
root = treeinput()
print(GetHeighAndCheckBalanced(root))
print(isBalanced2(root))
# Out:
# 1
# 2
# 4
# 5
# -1
# -1
# -1
# -1
# 3
# -1
# 6
# -1
# -1
# (4, False)
# False

# %% [markdown]
# ### diameter of tree

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def diameter(root):
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    if root is None:
        return 0,0
    lh,ld = diameter(root.left)
    rh,rd = diameter(root.right)
    h = 1+max(lh,rh)  # we are adding 1 because lh calculate the total node on left so we have to add 1 for root 
    diawithroot = 1+lh+rh   # see notes for better understanding
    dia =  max(ld,rd,diawithroot)
    return h,dia
    pass

def diameter2(root):
    height,dia = diameter(root)
    return dia

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
h,dia = diameter(root)
print(diameter2(root))
# Out:
#   8 3 10 1 6 -1 14 -1 -1 4 7 13 -1 -1 -1 -1 -1 -1 -1
# 7

# %% [markdown]
# ### Level wise input   (MAIN INPUT)

# %%
import queue
class BinaryTreeNode: 
    def __init__(self,data):
        self.data = data
        self.right = None
        self.left = None
    
def printtree(root):
    if root is None:
        return
    print(root.data,end=': ')
    if root.left is not None:
        print('L',root.left.data,end=', ')
    if root.right is not None:
        print('R',root.right.data,end='')
    print()
    printtree(root.left)
    printtree(root.right)
    
def LevelWiseInput():
    q = queue.Queue()
    print('Enter root data')
    rootData = int(input())
    if rootData is -1:
        return None
    root = BinaryTreeNode(rootData)
    q.put(root)
    while not q.empty():
        curr_node = q.get()
        print('Enter the left child of',curr_node.data)
        leftChildData = int(input())
        if leftChildData is not -1:
            leftChild = BinaryTreeNode(leftChildData)
            curr_node.left = leftChild
            q.put(leftChild)
        
        print('Enter the right child of',curr_node.data)
        rightChildData = int(input())
        if rightChildData is not -1:
            rightChild = BinaryTreeNode(rightChildData)
            curr_node.right = rightChild
            q.put(rightChild)
    return root

root = LevelWiseInput()
printtree(root)
# Out:
# Enter root data
# 1
# Enter the left child of 1
# 2
# Enter the right child of 1
# 3
# Enter the left child of 2
# 4
# Enter the right child of 2
# 5
# Enter the left child of 3
# -1
# Enter the right child of 3
# 5
# Enter the left child of 4
# -1
# Enter the right child of 4
# -1
# Enter the left child of 5
# -1
# Enter the right child of 5
# -1
# Enter the left child of 5
# -1
# Enter the right child of 5
# -1
# 1: L 2, R 3
# 2: L 4, R 5
# 4:
# 5:
# 3: R 5
# 5:

# %% [markdown]
# ### Print level wise

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def printLevelWise(root):
    # Given a binary tree, print the tree in level wise order. For printing
    # a node with data N, you need to follow the exact format: 
    # N:L:x,R:y
    # wherer, N is data of any node present in the binary tree. x and y are the
    # values of left and right child of node N. Print -1. if any child is null.
    # There is no space in between. You need to print all nodes in the level
    # order form in different lines.
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    if root is None:
        return
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        curr = q.get()
        currData = curr.data
        left = -1
        right = -1
        if curr.left != None:
            left = curr.left.data
            q.put(curr.left)
            
        if curr.right!=None:
            right = curr.right.data
            q.put(curr.right)
            
        print(currData, ':L:', left, ',R:', right, sep='')
    pass

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main 
levelOrder = [int(i) for i in input().strip().split()]
root = buildLevelTree(levelOrder)
printLevelWise(root)
# Out:
# 2 3 1 4 -1 -1 -1 -1 -1
# 2:L:3,R:1
# 3:L:4,R:-1
# 1:L:-1,R:-1
# 4:L:-1,R:-1

# %% [markdown]
# ### tree using preorder and inorder

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def buildTreePreOrder(preorder, inorder):
    # Given Preorder and Inorder traversal of a binary tree, create the binary
    # tree associated with the traversals.You just need to construct the tree
    # and return the root. For 12 Nodes with following input:
    # preOrder: 1 2 3 4 15 5 6 7 8 10 9 12
    # inOrder: 4 15 3 2 5 1 6 10 8 7 9 12
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    prelength = len(preorder)
    inlength = len(inorder)
    if prelength!=inlength or inorder is None or inorder is None or prelength==0:
        return None
    root = BinaryTreeNode(preorder[0])
    rootIndex = inorder.index(root.data)
    root.left = buildTreePreOrder(preorder[1:rootIndex+1], inorder[:rootIndex])
    root.right = buildTreePreOrder(preorder[rootIndex+1:], inorder[rootIndex+1:])
    return root

def printLevelATNewLine(root):
    # Given a binary tree, print the level order traversal. Make sure each level
    # start in new line.
    if root==None:
        return
    inputQ = queue.Queue()
    outputQ = queue.Queue()
    inputQ.put(root)
    while not inputQ.empty():
        while not inputQ.empty():
            curr = inputQ.get()
            print(curr.data, end=' ')
            if curr.left!=None:
                outputQ.put(curr.left)
            if curr.right!=None:
                outputQ.put(curr.right)
        print()
        inputQ, outputQ = outputQ, inputQ

# Main
n=int(input())
preorder = [int(i) for i in input().strip().split()]
inorder = [int(i) for i in input().strip().split()]
root = buildTreePreOrder(preorder, inorder)
printLevelATNewLine(root)
# Out:
# 12
# 1 2 3 4 15 5 6 7 8 10 9 12
# 4 15 3 2 5 1 6 10 8 7 9 12
# 1
# 2 6
# 3 5 7
# 4 8 9
# 15 10 12

# %% [markdown]
# ### tree from Inorder and postorder

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def buildTreePostOrder(postorder, inorder):
    # Given Postorder and Inorder traversal of a binary tree, create the binary
    # tree associated with the traversals.You just need to construct the tree
    # and return the root. For 8 Nodes with following input:
    # postOrder: 8 4 5 2 6 7 3 1
    # inOrder: 4 8 2 5 1 6 3 7
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    postlen = len(postorder)
    inlen = len(inorder)
    if postorder == None or postlen!=inlen or postlen==0 or inlen == 0:
        return None
    root = BinaryTreeNode(postorder[-1])
    rootIndex = inorder.index(root.data)
    root.left = buildTreePostOrder(postorder[:rootIndex], inorder[:rootIndex])
    root.right = buildTreePostOrder(postorder[rootIndex:-1], inorder[rootIndex+1:])
    return root
    pass

def printLevelATNewLine(root):
    # Given a binary tree, print the level order traversal. Make sure each level
    # start in new line.
    if root==None:
        return
    inputQ = queue.Queue()
    outputQ = queue.Queue()
    inputQ.put(root)
    while not inputQ.empty():
        while not inputQ.empty():
            curr = inputQ.get()
            print(curr.data, end=' ')
            if curr.left!=None:
                outputQ.put(curr.left)
            if curr.right!=None:
                outputQ.put(curr.right)
        print()
        inputQ, outputQ = outputQ, inputQ

# Main
n=int(input())
postOrder = [int(i) for i in input().strip().split()]
inorder = [int(i) for i in input().strip().split()]
root = buildTreePostOrder(postOrder, inorder)
printLevelATNewLine(root)
# Out:
# 8
# 8 4 5 2 6 7 3 1
# 4 8 2 5 1 6 3 7
# 1
# 2 3
# 4 5 6 7
# 8

# %% [markdown]
# ### node greater than x

# %%
import queue
class BinaryTreeNode:
    def __init__(self, data):
        self.data = data
        self.left = None
        self.right = None

def countNodesGreaterThanX(root, x):
    # Given a Binary Tree and an integer x, find and return the count of nodes
    # which are having data greater than x.
    #############################
    # PLEASE ADD YOUR CODE HERE #
    #############################
    if root is None:
        return 0
    result = 0
    if root.data>x:
        result+=1
    result+=countNodesGreaterThanX(root.left, x)
    result+=countNodesGreaterThanX(root.right, x)
    return result
    pass

def buildLevelTree(levelorder):
    index = 0
    length = len(levelorder)
    if length<=0 or levelorder[0]==-1:
        return None
    root = BinaryTreeNode(levelorder[index])
    index += 1
    q = queue.Queue()
    q.put(root)
    while not q.empty():
        currentNode = q.get()
        leftChild = levelorder[index]
        index += 1
        if leftChild != -1:
            leftNode = BinaryTreeNode(leftChild)
            currentNode.left =leftNode
            q.put(leftNode)
        rightChild = levelorder[index]
        index += 1
        if rightChild != -1:
            rightNode = BinaryTreeNode(rightChild)
            currentNode.right =rightNode
            q.put(rightNode)
    return root

# Main
levelOrder = [int(i) for i in input().strip().split()]
x=int(input())
root = buildLevelTree(levelOrder)
print(countNodesGreaterThanX(root, x))
